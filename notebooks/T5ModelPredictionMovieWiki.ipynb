# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install torch
# !pip install rich[jupyter]
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 6.1MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/d5/f4157a376b8a79489a76ce6cfe147f4f3be1e029b7144fa7b8432e8acb26/transformers-4.4.2-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 6.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 23.9MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/08/cd/342e584ee544d044fb573ae697404ce22ede086c9e87ce5960772084cad0/sacremoses-0.0.44.tar.gz (862kB)
#      |████████████████████████████████| 870kB 36.7MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=f9d102720e0d9ffceda725c32ad1ffa6f2b3da984541a9b7d3445a29dbdb5134
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.44 tokenizers-0.10.1 transformers-4.4.2
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Collecting rich[jupyter]
#   Downloading https://files.pythonhosted.org/packages/1a/da/2a1f064dc620ab47f3f826ae085384084b71ea05c8c21d67f1dfc29189ab/rich-10.1.0-py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 5.0MB/s
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich[jupyter]) (3.7.4.3)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl (51kB)
#      |████████████████████████████████| 51kB 4.0MB/s
# Collecting colorama<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich[jupyter]) (2.6.1)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.5.1; extra == "jupyter" in /usr/local/lib/python3.7/dist-packages (from rich[jupyter]) (7.6.3)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (4.10.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.5.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.3.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.3.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (54.2.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.9.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (2.11.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (5.6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (22.0.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (2.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.4.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (3.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0.0,>=7.5.1; extra == "jupyter"->rich[jupyter]) (2.4.7)
# Installing collected packages: commonmark, colorama, rich
# Successfully installed colorama-0.4.4 commonmark-0.9.1 rich-10.1.0

# %%
import os
import re
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook, tnrange
from sklearn.utils import shuffle
import pickle
import math


import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler

# Importing the T5 modules from huggiazngface/transformers
from transformers import T5Tokenizer, T5ForConditionalGeneration

# rich: for a better display on terminal
from rich.table import Column, Table
from rich import box
from rich.console import Console

# define a rich console logger
console = Console(record=True)

training_logger = Table(
    Column("Random Selection", justify = "center"),
    Column("Epoch", justify="center"),
    Column("Loss", justify="center"),
    title="Training Status",
    pad_edge=False,
    box=box.ASCII,
)

valid_loggger = Table(
    Column("Random Selection", justify = "center"),
    Column("Loss", justify = "center"),
    title="Validation Status",
    pad_edge=False,
    box=box.ASCII,
)

def save_pickle(path, obj):
  with open(path, 'wb') as fp:
    pickle.dump(obj, fp)

def load_pickle(path):
  with open(path, 'rb') as fp:
    return pickle.load(fp)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
torch.manual_seed(3007)

# %%
model = T5ForConditionalGeneration.from_pretrained('drive/MyDrive/T5MovieWikiTraining2_0/outputs-itr-3/model_files')
tokenizer = T5Tokenizer.from_pretrained('drive/MyDrive/T5MovieWikiTraining2_0/outputs-itr-3/model_files')

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
greedyOp = model.generate(input_ids, max_length=100)
tokenizer.decode(greedyOp[0], skip_special_tokens=True)
# Out:
# 'filming a series of shorts, shorts, and extended scenes, all starring small-time hero Jack. Jack is a solitary, solitary, and physically demanding man who is possessed by a spirit that he cannot live without. He is possessed by a spirit that he cannot live without, and is possessed by a spirit that cannot live without. Jack is a serial killer who is known to his friends as "'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=100,
    num_beams = 5, 
    early_stopping = True
    )
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 'filming a series of shorts, shorts, and interlaced pieces of furniture, all of which are indistinguishable from each other.[2]'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=200,
    num_beams = 3, 
    early_stopping = True,
    no_repeat_ngram_size = 2
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 72
# 'filming a series of shorts, two main characters are shown dead in the background, with the female lead appearing in each scene. The male lead, who appears to be in his mid-thirties, is shown to have possessed all of the characters before he was killed, while female leads appear to appear in both roles.'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=200,
    num_beams = 3, 
    early_stopping = True,
    no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 0
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 41
# 'filming a series of murders, a group of people are murdered and the film ends with a bang on the head of a local psychiatric hospital.'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1000,
    num_beams = 3, 
    # early_stopping = True,
    no_repeat_ngram_size = 3,
    # do_sample = True, 
    # top_k = 0
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 110
# "filming a series of shorts, shorts and episodic pieces, with interlaced flashbacks showing the events of the previous film, including a scene in which a woman is killed in a car accident and an attempted suicide by a man in his car. The scene then switches to a flashback, in which the woman is confronted by the man's fiancée, who is also killed in the car accident, and then relives the events as they happened."

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 0,
    temperature = 0.7
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 200
# "film editor Max Machin is reporting on his son's sexual experiences in London. Max's jealousy is heightened when he is approached by his ex-wife, who reveals that Max's pregnancy has been arranged for him. He tells Max that she has a baby and she begins to experience strange feelings for him. Max ends up in a hospital with a baby girl, who turns out to be the one who died in the accident. Max starts to see strange things about Max after he has left him. Max, now a sex addict, attempts to nurse Max to a newborn, but Max is soon attacked by a rogue student, who is rescued by Max. Max and Max get caught in a rage and are later murdered by Max, who stabs him in the thigh. Max, Max and Max escape from the scene and escape the horrors of Max's death."

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    # temperature = 0.7
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 174
# 'film producer Gerard Slaughter (Colman) works under the pseudonym "Pvt. Pvt. Pliny" who has a personality different from his own. His passion is to produce movies with low budgets. His ideal movie version is a modern "house of dreams" but he prefers the cinematic one. He dreams of a singer/dancer on the radio and after recording a live band gig, he plans to perform a live concert at the Motel. His vision of the singer is palpable, not caring about the audience, but to the point of attempting to entertain audience members, including his ex-wife, Maize (Jonathan Szeta) and his teenage daughter Maya (Manion Gleason).'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 0,
    top_p = 0.90
    # temperature = 0.7
    )
print(len(beamOp[0]))
tokenizer.decode(beamOp[0], skip_special_tokens=True)
# Out:
# 200
# 'film opens in the year 1942, in the period of medieval Egypt, when king Henry VIII of England arrived at the castle after the Normandy invasion. The Scottish protectorate of the castle, Majector of Achille, is determined to restore the castle to its former glory. Prof. Chan, with his ministerial assistants, assist the governor by arranging an evacuation for the town of Sardinia. Prof. Chan is on the run from Sardinia and prevents him from being shot at by the Turks. The Turks control their guardians and guards at the castle, which was guarded by a henchman Alexander Inverness, and introduces himself as a revolutionary for the Romans. Through letters written to the Governor of Sardinia, he finds out that Arya has been tortured by Greek prisoners, and her father is in the care of Count Maya of Ar'

# %%
text = "generate plot for genre: horror"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))

# %%
from pprint import pprint

# %%
text = "generate plot for genre: horror comedy"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))
# Out:
# Op: 0----------------------------------------------------------------------------------------------------
# 825
# ('the film, opens with a group of two creeps preparing to cross the deserted '
#  'deserted marshes. The film follows the first of four creepy-crazy teenagers '
#  'exploring a deserted marshes.')
# Op: 1----------------------------------------------------------------------------------------------------
# 825
# ('set in 1898, the story follows a group of British soldiers led by Lieutenant '
#  'Colonel Joseph Hepburn who, among others, are molesting young '
#  'African-American soldiers. The soldiers are soon seen running around the '
#  'country helping the refugees and returning home. While the group is in the '
#  'process of clearing the prison, the soldiers get robbed and beaten up by the '
#  'masked recruits. At the end of the first day, they are apprehended by '
#  'General Arangos (P. D. Atkins) who has escaped with his men in a carjacking, '
#  'and a chain containing a necklace marked "Darkness in the Eye", which '
#  'contains "The Four Paws". There, they are able to kill the people who rob '
#  'them, though the first three remaining remaining soldiers survive. The '
#  'defenseless are determined to get the necklace back, but they are chased by '
#  'the narrator of the title, Jack (Paul Fard) and a local crooked barmaid '
#  '(Paulo Pietro) chase him to the door. Jack chases the boys to the front of '
#  "the castle where Jack's head is found and is carried to the main entrance by "
#  'a deranged bumbling Frenchman (Danny Dolores) who accompanies them. Jack '
#  'then tries to chase the boys around the castle until they reach the back '
#  'door before the police arrive. Jack then tries to yell at him but finds that '
#  'he is the "f***ing man" and runs back to the tent after being shot in the '
#  'leg. The girls leave, but Jack kills them. Meanwhile, Mike returns to the '
#  'bunker, where he is introduced to his wife and sister. Mike rescues them and '
#  'saves her from being raped. Later, he and the girls find themselves in a '
#  'room occupied by a serial killer, Dracula (Barry Burns), but the men attempt '
#  'to kill Mike. A second victim is revealed to be Tony (Danny Parker), a '
#  'survivor of a car bomb at a church in Scotland. The men soon discover that '
#  'they lost their last leg and head for the chapel, while he is attacked by a '
#  'band of clowns led by Mike, who kills them. He flees, but suddenly the '
#  'groups retreat and reunite. Meanwhile, the brothers arrive and help Mike to '
#  'flee again. Mike, Danny, Adam, and Steve are all attacked by the ghost, with '
#  'Mike and Steve leaving. Mike and Steve hide together in a retaliated '
#  'explosion. Mike and Steve take part in the robbery and crash to safety. Mike '
#  'complies and leaves, but Mike manages to escape, but Mike kills Steve, which '
#  'kills Steve and Jake. They set out to the grave of the ghost, which ends up '
#  "in a zombie cave, killing Dave, Steve, Danny, and Steve's men, and Steve's "
#  'two younger sons. Jim and Steve realize how strange things happen in that '
#  'they had formed to be together. Jake loses his family and their cars, with '
#  'Mike having had a violent disagreement with his wife, and tormenting Steve '
#  'as a result he now has to take over the family business. Steve is now '
#  "bringing Julie to the home of Steve's brothers. A man, Steve, falls in love "
#  'with Julie, but Steve falls through the chimney, and takes the cloak, '
#  'breaking him off. Steve becomes upset, but he starts telling Guy about the '
#  'crime, as he has been thrown out of the house after he finds Julie and her '
#  "parents killed during a car accident. Steve's henchmen (Bill Stewart, Corey "
#  'Moore, and Danny McElready) find the body. Gary is injured during the first '
#  "and only sister of Steve's sister Jane")
# Op: 2----------------------------------------------------------------------------------------------------
# 825
# ('film begins with an abandoned aristocratic mansion being inhabited by a '
#  'mystical snake who goes by the name of "Lord of the Dead". Upon arrival at '
#  "the abandoned aristocracy's palace, Lord Of The Flies encounters a series of "
#  'bizarre murders, performed by various priests, in order to obtain a more '
#  'modern appearance. He finds a cryptic message, suggesting that the cryptic '
#  'message is the part of the mystery that has been missing for some time. The '
#  'cryptographers explain to the cryptographers that the departed have '
#  'encountered mystical creatures and sought out and killed those killed for '
#  "them. On arrival at the castle, the priests claim that they saw the woman's "
#  "corpse while they were under their house's care, but she soon revealed her "
#  'sins. Dracula sets out to retrieve the corpse and retrieve it. When he '
#  'returns, he finds that it belongs to a man named Paula, the daughter of a '
#  'local witch. Paula has a vision of his tomb and is certain that her husband '
#  'is the reason why he believes Paula is innocent. Paula visits the castle to '
#  'see how the ghost is being held. When Lord Marquis of Grenada stops him, he '
#  'comes to find the temple and reveals his plan to save the house by giving '
#  'the ghost to the witch. A frightened Paula disobeys orders and murders '
#  'Paula. Paula and Paula move in together in one big group. Paula arrives at '
#  'the chapel to observe a vision of the new-born monk named Thorn, who falls '
#  'in love with Thorn. Later, the priest orders Peter to bury Thorn in the '
#  'tomb, but before he can do so, Paula leaves to take her hostage. Paula is '
#  "caught, and later meets Dracula, a man who claims to be Thorn's nephew. When "
#  'Paula comes back to him, he kills Thorn, but Sir Peter says he loves Thorn. '
#  "Paula's spirit heals him, and she turns him over to the priest. Dracula and "
#  'Peter are joined by the spirit of Dracula and Paula, who says that Dracula '
#  'must have been himself, but Mary is already demonically cast out by Dracula. '
#  'Paula gets involved with Dracula to kill Dracula. However, Dracula gets his '
#  'daughter Mary to help her. Paula then meets the ghost of the mob, who '
#  'reveals he killed himself when the corpse was uncovered by Dracula. Ascended '
#  'to the spirit, Dracula and Peter and Mary confront Dracula and deliver Mary '
#  'into a body. Dracula confronts Mary and asks her father, who accepts her and '
#  'warns her against the Mob as he is evil. Mary is killed and is taken to '
#  'hospital after suffering wounds from the body. Later on Mary gives the Mob '
#  'the name Margot Rose. She has now bitten the mob, but Mary has bitten her '
#  'and is possessed by Dracula. Mary claims to have had the same exact same '
#  'curse, but Mary and Dracula believe him to be')

# %%
text = "generate plot for genre: romantic comedy"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))
# Out:
# Op: 0----------------------------------------------------------------------------------------------------
# 469
# ('the fictional characters (Adrian, Catherine, Rupert, Carstairs, and Leo) in '
#  'the comic books series Paranormal: The Lost Marriages of Two Cass Boys '
#  '(Forrest, Americ, and Molly), who are part of a gang of six witches to be '
#  'hunted down by the Frogs. A timid and cynical Farrell (Peter Parker), known '
#  'as The Lost Queen of the Lost Land, is hired as a stagehand to portray The '
#  'Lost Queen of the Lost Queen in the 1920s (with Peters as the lead '
#  'character) to play a role in the titular role), and he finds himself quickly '
#  "drawn into the world of the Lost Queen (through Peters' conceit and his "
#  're-birth and the end of The Lost Queen), whose only purpose is to obstruct '
#  'its fate. But when a prince comes along, he kills the princess.')
# Op: 1----------------------------------------------------------------------------------------------------
# 469
# ('film premiered June 8, 1978. It centers on a woman, Cassidy Gombell (Anne '
#  'Balfour), who falls in love, and the two realize their estranged mom is not '
#  'caring. While making love, she has been having an affair with one of her '
#  'best friends, Joe (Ted Denton), whose girlfriend, Julie (Kate Hudson), was '
#  "expecting a child. Unfortunately, the two fall in love, and when Joe's "
#  'girlfriend, Julia (Jaclyn Lynch), comes to the studio to discuss their '
#  'romance, Cassidy decides to stay with her. When she comes to the studio she '
#  'uncovers her true identity and contacts her mother, Ms. McQueen (Nicholas '
#  'Anderson).')
# Op: 2----------------------------------------------------------------------------------------------------
# 469
# ('film opens with David Soto (Ryan Joplin) leaving for Spain to attend the '
#  'Oscars, where he meets a French comedian called Saviour (Ted de Corsia). The '
#  'two fall in love and immediately start dating. David helps Saviour to '
#  'compose the music for Saviour and then directs the singer to his channel. '
#  'David is only interested in Saviour and he wants to get her to marry her. At '
#  'first he fails to impress Saviour. At the next meeting, David breaks up with '
#  'Saviour and tells Saviour about his desire to marry his girlfriend. Saviour '
#  'goes to meet him in Lisbon and asks him to tell Saviour that he loves her. '
#  'His attempts to explain why Saviour is upset at his choices and that he '
#  "doesn't want to. He tells Saviour that he doesn't like him, but he does. "
#  'When Saviour comes to Portugal to pick up the phone, he hears about it. He '
#  'is shocked and decides to come to Paris and introduces him to another girl '
#  'named "David". He then convinces Saviour that he doesn\'t have to tell him '
#  'anything, but tells him that he will come. Saviour gives Saviour a message '
#  'telling him that he will finally come back. Saviour will talk to him about '
#  'the future together, but Saviour rejects his advice. As Saviour begins to '
#  'form a romantic relationship with Saviour, the two fall in love. Saviour '
#  "invites Saviour to a party at Saviour's Inn. Saviour is introduced to the "
#  "Marquis. He is then told that he had taken Saviour's cake, but he is "
#  'disappointed that Saviour is all right with him. With his sidekick, Saviour '
#  'leaves, but soon gets irritated. After he returns, Saviour marries Saviour, '
#  'leaving Saviour and Saviour behind to inform Saviour that Saviour was '
#  'working for him. The pair finally settle down and decide to head back to '
#  'Italy.')

# %%
text = "generate plot for genre: psychological action thriller"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))
# Out:
# Op: 0----------------------------------------------------------------------------------------------------
# 712
# ('film was shot in a small village in occupied Pakistan, when a minister '
#  'arrived with his wife and three children and asked the Minister for advice '
#  'regarding making a film in his own village. After several years, the '
#  "minister was furious and decided to kill the minister's daughter. She then "
#  'took a line from newspaper to report the incident to the provincial council. '
#  'The film went on to feature over a period of six months, which included an '
#  'extended period of observation, observation, and a short film review. It '
#  "showed a surprisingly sharp and detailed description of the country's most "
#  'frequent occurrences, mostly with a sudden increase in crime. An old lady, '
#  'Ms. Choudhry (Kamal Haas) told her husband (Suhail Agarwal) that the '
#  'incident had a historical or historical significance to this area, pointing '
#  'out that the crime had been committed. This article was further extended by '
#  'one episode in a new film, where a new police inspector (Thilakan) reported '
#  'it. On the first day of the film, S.T. Chandra Chakravarty (Daisy Hayek) has '
#  'contacted several people who knew about this case and she has written to '
#  'them that the document which was sent was in the local embassy. Suddenly the '
#  'police were on the train, and Chakravarty ariel telephone call came from the '
#  'home of the young girl he spoke to, stating that the she lied to him about '
#  'how she wanted to speak and what the woman said. At the time of the call, '
#  'the he rescued the girl but they both had sex to get to know the girl. '
#  "Chakravarty visited a shaman for an oral interview and found the woman's "
#  'body. They got to know that Chakravarty, a girl from a nearby village, was '
#  'also from that village; the woman was another woman. In the meantime, they '
#  'were visited by Samsaleen alias Shetty, who came to talk to Chopra. They '
#  'were confronted by the village head who tried to explain to her why this '
#  'was. That night, when it came to the place, they were questioned by their '
#  'village head. Shocked by what had happened, Samsaleen was taken aback by '
#  'Tanikoth and the narrator in her book, telling Samsaleen that she was "as '
#  'insane" and that he was the one who ruined a society to destroy such a '
#  'society. She went with him to a party with his friends and saw one of the '
#  'group going down with him. She got his picture and talked to him. Samsaleen '
#  'made a reference to her dream. When he got a copy, his friend took Samsaleen '
#  'away to Spain. The next day Samsaleen (and Samsaleen) pounced on his new '
#  'vision and was pleading with him to release him because he still loved '
#  'Samsaleen. Samsaleen reached France by plane for a visit from France and '
#  'eventually made Samsaleen and got him hired as a cook. Samsaleen apologetic '
#  'when Samsaleen canceled his meeting')
# Op: 1----------------------------------------------------------------------------------------------------
# 712
# ('film begins with the introduction of a Japanese Tai-chi-san that is playing '
#  'a tennis tournament. As he plays a match with a Suoudai racial abuser, he '
#  'realizes his mistake and becomes suicidal.')
# Op: 2----------------------------------------------------------------------------------------------------
# 712
# ('film opens with a bang for the buck that Jack has on his wife, Laurel. Jack '
#  'enters a hotel, has a drink, and they both proceed to open the bar. Jack is '
#  'hysterical and in a rage, and he gives her several mugs that he takes for '
#  "himself. Jack's former girlfriend is a bomber-man named Tom, who was "
#  'arrested for treason. Nick is called by the police to inform Jack that he '
#  'has been inducted into a crime scene and that he is on the run from the '
#  "police. He quickly becomes involved with Nick's former girlfriend Jolie, who "
#  'he has recently murdered. While talking to Jolie, Jack enters her house, and '
#  'finds out Jolie has left the house. Jack, meanwhile, is the only one the '
#  'policeman in the room, and Jack tells her that he has given her a gun. Nick '
#  'then tells Jack that his girlfriend tries to shoot Jack, but Jack tells the '
#  'truth while he is gone. But Jack tries to warn Jolie that she has promised '
#  'her to never use him. They then find out that Jack has changed his mind. In '
#  "doing so, Jack and Jack find out about Jack's identity and that Jolie is "
#  'actually Jack. During this time, Jack learns that Jolie was a school teacher '
#  "and she was the child of Jack's father. Jack wants to go to the police "
#  "department and he is waiting for him. Jack and Jolie's father have a "
#  'relationship and Jack feels they should be together. The film ends with Jack '
#  'noticing how the police (including Jack) are being interrogated by a gunman.')

# %%
text = "generate plot for genre: psychological action thriller director: Anurag Kashyap"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))
# Out:
# Op: 0----------------------------------------------------------------------------------------------------
# 836
# ('film opens with a kidnapping of a girl from Delhi, Pratap Choudhary. He '
#  'meets Chinna, a beautiful but uninterested young lady from Chennai, who '
#  'teaches students psychology. He gives a lecture on the subject to deviating '
#  'into society, and has a flashback to her mother as well. This is a lesson '
#  'for Pratap that the police must now do more to maintain order and control '
#  'their lives. The movie starts with a young man Dharmendran(Devadasa Kote) '
#  'who asks Pratap what he wants to do and it moves on. He also makes a mockery '
#  'of the young woman, and appoints her to take care of her. The young man, '
#  'Dharmendran is a narrator for the film, who has a super-charged character '
#  'named Kalyanath Kashyap, who is very good at acting. One night he comes '
#  'across Kalyanath Kashyap and realises that Kalyanath is actually a '
#  'paranormally gifted person, who was sexually abducted by the devil and '
#  'killed by his cousin Manorama and is about to die. Before the death of his '
#  'parents, Kumar Kumar appoints an emissary to investigate the case and find '
#  'out why he was abducted. He gets to know a man who came to take her out to '
#  'kill a priest. Kumar, getting up from bed, is attacked by the same murderer, '
#  'however he is shocked to see that he is his uncle. Kumar, realizing that the '
#  'man was supposed to be the killer, orders Kumar to return to his house. '
#  'Kumar then lies to Kumar at the police station where the killer is held '
#  'captive. He then attempts to escape from the prison by taking him to his own '
#  'hotel, where Kumar becomes a suspect. Kumar enlists the help of Raja, the '
#  'narrator of a movie about a girl named Paloma. Kumar and Paloma play out the '
#  'film with the help of a singer. Kumar manages to escape the murder, but '
#  'Kumar saves Paloma by putting him on a high wire. When Kumar is discovered '
#  'guilty in court, he seeks him out of a conspiracy within a frame. The court '
#  'asks Kumar to stay away from him, even though Paloma said he is at peace '
#  'with Kumar. In the end Kumar and Paloma have a peaceful life together.')
# Op: 1----------------------------------------------------------------------------------------------------
# 836
# ('film begins with one male protagonist Jadav (Satyanarayana) resigned from '
#  'her job in a clothing shop when her brother Koshya (Sev Chhelavaran) '
#  'threatened to kill him. She immediately swooped at him and he ran away. He '
#  "wanted to kill her if she didn't give him a money. He wanted to extort Rs. 3 "
#  'lakh by mail, but the money flown by Jadav suddenly stopped. In a panic, '
#  'Jadav runs away from the location. It ends with a gunman and another girl '
#  'Anurag Kashyap (Anurag Kashyap) rescuing her, and their son, Narasimha '
#  '(Sharmila Mohan). She meets Faridula, the daughter of Siddri and they become '
#  'friends. She becomes ill and is now pregnant. They have three children, two '
#  'young brothers. Her father, an armed robber, has a crush on him and his '
#  'father has also kidnapped his family. He comes to know of such a kidnapping, '
#  'and he gives her money. With no money, she betrays him. He has a child, who '
#  'is also on the run from Faridula, but he does not want to know her. He also '
#  'tells her that Faridula is pregnant. He gives her $300,000 and hires a '
#  'police police officer (Pradeep Kapoor) to enlist his help. He manages to rob '
#  'a small jewelry shop. He learns that Faridula had been a regular witness to '
#  "his husband's robbery. After this he gets a phone call from Faridula, "
#  'stating that the phone number is going to get lost. As the telephone rings, '
#  'he offers him the money to buy a new car. He goes to Punjab for a visit, but '
#  'does not hear anything. He goes to Punjab for a visit but is rejected and '
#  'sent for further protection. Faridula goes to Punjab for a part-time job, '
#  'where he tells his boss that he should arrange the business deal with '
#  "Maheswaran, where he will pay Jadeswaran's salary. Jadeswaran discovers that "
#  "Jadeswaran, having betrayed his father's money, has even kidnapped him. "
#  "Jadeswaran's son Bhagavathar comes to know that Jadewaran's family are "
#  'staying at the apartment. Jadewaran arrives at Nainital where he meets '
#  'Jadewaran, who has a son. Jadewaran confronts his son and reveals that there '
#  'is a conspiracy between Jadewaran and Jadewaran, and that they could have '
#  'bought a car from Jadewaran. Jadewaran reveals that he has the money and '
#  'would be used for the city estate. Meanwhile, Jadewaran is also trying to '
#  'get hold of Jadewaran and his son, while he is a local policeman, who has '
#  "recently been to jail. There is also an explosive bag at Jadewaran's house. "
#  "He attempts to bring Jadewaran to Jadewaran's place and arranges it for him, "
#  'before Jadewaran reveals that Jadewaran sent Jadewaran, as his house will be '
#  'bombed. Jadewaran is seen by Nadita (Damien Ali) to arrest Jadewaran. After '
#  'a long fight, Jadewaran attacks Jadewaran, and he captures Jadewaran and he '
#  'has repurchased a diamond. However, Jadewaran comes to know that Jadewaran '
#  'and Yasu')
# Op: 2----------------------------------------------------------------------------------------------------
# 836
# ('film opens with a beautiful and glamorous Madhu, who is a former gyaru, who '
#  'is now a corporate legal professional working for the public sector agency '
#  'in Hyderabad. She is the daughter of a local businessman, Vasu, who has been '
#  'a widow since childhood. Their only real assets are her marriage to Suman, '
#  'who is a widow and a cricketer. He lives alone, with her brother, Vasu and '
#  'his wife, Devaraj. Her father seems to take care of her while Devaraj tries '
#  'to get her married. However, he is concerned about her safety, as she is '
#  'unable to afford to pay her out of his creditors. When he explains that his '
#  'role in politics is beyond obvious and he is not ready for anything more. '
#  'Sometime later, his brother returns from Bengal, where he makes arrangements '
#  'to meet his cousin, Ajay, in order to meet with her. He then meets Ajay, who '
#  "has an eye on her, but does not know if he is an honest person. Ajay's wife, "
#  'Anurag Kashyap, plans to sell the house to the businessman Brahmin '
#  'Maheswari, for $200,000. These arrangements are confirmed when he asks for '
#  'his money and agrees. After an inconsequential meeting between the two of '
#  'them, he meets an attractive lady, Pushpa (Rudra Khanna). Pushpa learns of '
#  "Pushpa's involvement with Pushpa, his lawyer and one of his associates, "
#  'Sumitra, also proposes for her to marry him. Pushpa is already in love with '
#  'a boy, Manipul, but on his return, he resigns from the job. The next day, '
#  'Pushpa is unable to express his interest, as the two misunderstandings are '
#  'causing Manipul to end up in jail. Pushpa, who has become a police officer, '
#  'finds out that a police officer is the man with a problem, and becomes a '
#  "detective, even though Manipul isn't as friendly to him, and that Manipul is "
#  'the owner of a luxury car. Manipul is not the man under the custody of a '
#  'state, and that he will be sent to jail. Meanwhile, Manipul is asked to take '
#  'photos of people outside her residence. After a long spell, Manipul accepts. '
#  'Manipul immediately starts filming. Manipul notices that Manipul did not '
#  'bother him at all, but with an exuberant contrite. Manipul arranges a video '
#  "shoot of him for the film and decides to go back on to see Arjun's place. He "
#  'takes Manipul to the police station and, having heard the video, manages to '
#  "capture Manipul's handshake in the bank account. Manipul calls his cousin "
#  'Hari, who calls him Chinuhara (Pasupathy), who has already signed a contract '
#  'for an exclusive business trip. One day, Sher Khan demands the money, not '
#  'sure where to go. So she goes to Raj, who tells him her true identity. He '
#  'comes, and realizes the purpose of killing him. He goes to Raj to arrange '
#  'the money to make him an offer that he plans. However, she sees Raj and '
#  'makes him promise that he will not compromise the couple forever. She tells '
#  'him that Raj, her new friend and assistant, gets jealous of her and asks her '
#  'out for his money. Raj, now angry, sends his gang to Hyderabad for approval. '
#  'He meets Raj and initially agrees but after he passes, Raj and Jomu join '
#  'forces and gets out of the house. Raj and Jomu leave and asks Jomu to let '
#  'her go.')

# %%
text = "generate plot for genre: psychological action thriller director: Anurag Kashyap and ethnicity: Bengali"
input_ids = tokenizer.encode(text, return_tensors="pt")
beamOp = model.generate(
    input_ids, 
    max_length=1200,
    # num_beams = 3, 
    # early_stopping = True,
    # no_repeat_ngram_size = 3,
    do_sample = True, 
    top_k = 100,
    top_p = 0.95,
    num_return_sequences=3
    # temperature = 0.7
    
    )
for i, sample_op in enumerate(beamOp):
  print(f'Op: {i}' + 100 * '-')
  print(len(sample_op))
  pprint(tokenizer.decode(sample_op, skip_special_tokens=True))
# Out:
# Op: 0----------------------------------------------------------------------------------------------------
# 1200
# ('film revolves around a village, with a recurring theme "There is no danger '
#  'in living a life". In fact, every village has a different set of rules and '
#  'rules. The Chief Minister is a concerned citizen and often the only one who '
#  'wants to know what happens to the people. He and his wife are always in '
#  'search of the right kind of people. He decides to talk to a friend of a '
#  'local politician who is having issues with his family. His only choice is to '
#  'expose the murder of a minister. His friend Vikram, who is also struggling '
#  'to raise funds for his education, takes a good job and helps his friend. One '
#  'day, Vikram catches a snake which attracts the attention of a snake. One day '
#  'he is attacked by a group of thugs, who say that there are only three people '
#  'in the city but none of them are able to find the girl in the neighbourhood. '
#  'It is revealed that the father of the child is not who he claims to be. His '
#  'uncle, with the help of a local gang, wants to find the girl with the money '
#  'and gives her the money he needs. His father, a businessman, orders him to '
#  'donate the money to a charity which he can borrow. Now, he offers to sell a '
#  'lot of land in Bengali. The wife of the man with the money is a corrupt '
#  'politician called Jai Gowri. The deceitful Jai Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri '
#  'Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Gowri Go')
# Op: 1----------------------------------------------------------------------------------------------------
# 1200
# ('film opens in a small town; Panikkar, a boy from Calcutta who lives with his '
#  'wife, was a schoolgirl, who is in love with Manohar Kashyap, a middle class '
#  'girl. His father is to hold a university, Gowri Pooja, away from them, from '
#  'an impulse to kill him, is a successful punk. His first hit is a run in with '
#  'gangster, Banerjee, who is all but a hoodlum who is the son of a rich '
#  'businessman, who later becomes a minister in his village. When he is finally '
#  'able to go to his house, Pooja runs away from her family after a few days, '
#  'but this is only the second time. He makes a plan to get rid of Banerjee, to '
#  'get his brother out of his family trouble. But things start to unravel when '
#  "Pooja is adamant that she can't go back to her family unless she keeps "
#  "telling him that she hates her boyfriend, and will go to jail if he doesn't "
#  'go back, he will end up being hanged. Pooja starts to unravel and his '
#  "uncle's idea is to take a loan from his brother and his family and to stop "
#  "his fraud. That's how Pooja tries to escape from his sister's grip, is his "
#  'only hope in life. In a climax, Pooja and his uncle are freed and his uncle '
#  'reveals that he had a child.')
# Op: 2----------------------------------------------------------------------------------------------------
# 1200
# ('film revolves around an old school master and his students. The film has a '
#  'subplot that entails a police raid on a temple by a group of youth known as '
#  '"Chittor", a notorious street gangster and a notorious for drinking liquor. '
#  'It concentrates on Sagar, a wealthy person who wants a quick and simple '
#  'solution for his problems. The film is one that deals with Tatyana, a woman '
#  'who was once a minister, and has a crush on her.')
